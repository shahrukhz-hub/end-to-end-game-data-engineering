# %%
# %sql
CREATE EXTERNAL LOCATION raw_location
URL 'abfss://raw@storageaccgameanalytics.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL game_analytics_creds);

CREATE EXTERNAL LOCATION curated_location
URL 'abfss://curated@storageaccgameanalytics.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL game_analytics_creds);

# %%
# %sql

CREATE CATALOG IF NOT EXISTS game_analytics;

CREATE SCHEMA game_analytics.bronze;
CREATE SCHEMA game_analytics.silver;
CREATE SCHEMA game_analytics.gold;
